# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Features e alvo
X = df.drop(columns=["cliente_id", "cancelou"])
y = df["cancelou"]

# Separar treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalização
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Modelo de regressão logística
model = LogisticRegression()
model.fit(X_train, y_train)

# Predição
y_pred = model.predict(X_test)

# Avaliação
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
import requests
import pandas as pd

# URL da API fictícia
url = "https://api.teleconx.com/clientes"

# headers (se a API exigir autenticação)
headers = {
    "Authorization": "Bearer SEU_TOKEN_API_AQUI",
    "Content-Type": "application/json"
}

# Fazendo a requisição
response = requests.get(url, headers=headers)

# Verificando se deu certo
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)  # Transformar em DataFrame
    print(df.head())
else:
    print("Erro na API:", response.status_code, response.text)

Passo 2 – Estrutura esperada dos dados
O dataset geralmente contém colunas como:
cliente_id
idade
tempo_contrato (meses)
plano
valor_mensal
qtd_chamados_suporte
atraso_pagamento
cancelou (variável alvo → 1 = cancelou, 0 = ativo)

# Informações gerais
print(df.info())
print(df.describe())

# Proporção de churn
print(df['cancelou'].value_counts(normalize=True))

# Médias comparando clientes que saíram vs. ficaram
print(df.groupby("cancelou")[["valor_mensal", "qtd_chamados_suporte", "tempo_contrato"]].mean())
import matplotlib.pyplot as plt

# Distribuição de cancelamentos
df['cancelou'].value_counts().plot(kind='bar')
plt.title("Distribuição de Evasão de Clientes")
plt.xticks([0,1], ["Ativos", "Cancelados"], rotation=0)
plt.show()

# Comparar valor mensal entre churn e não churn
df.boxplot(column="valor_mensal", by="cancelou")
plt.title("Valor Mensal vs Evasão")
plt.suptitle("")
plt.show()
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Features e alvo
X = df.drop(columns=["cliente_id", "cancelou"])
y = df["cancelou"]

# Separar treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalização
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Modelo de regressão logística
model = LogisticRegression()
model.fit(X_train, y_train)

# Predição
y_pred = model.predict(X_test)

# Avaliação
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
#   File "/tmp/ipython-input-145415327.py", line 51
#     Passo 2 – Estrutura esperada dos dados
#             ^
# SyntaxError: invalid character '–' (U+2013)
